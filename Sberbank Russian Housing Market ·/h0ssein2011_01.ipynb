# %%
import pandas as pd
import numpy as np
import zipfile
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
zf_train = zipfile.ZipFile('train.zip') 
zf_macro = zipfile.ZipFile('macro.zip') 
train = pd.read_csv(zf_train.open('train.csv'))
macro=pd.read_csv(zf_macro.open('macro.csv'))
merged=train.merge(macro,on='timestamp')

# %%
merged.head()
# Out:
#    id   timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq         ...          provision_retail_space_modern_sqm  \
# 0       NaN       NaN         ...                                      271.0
# 1       NaN       NaN         ...                                      271.0
# 2       NaN       NaN         ...                                      271.0
# 3       NaN       NaN         ...                                      271.0
# 4       NaN       NaN         ...                                      271.0
#
# ...

# %%
na_count=(merged.isnull().sum()/merged.shape[0])*100
na_count.sort_values(ascending=False)
# Out:
# provision_retail_space_modern_sqm         97.528798
# provision_retail_space_sqm                81.648124
# students_reg_sports_share                 55.465853
# museum_visitis_per_100_cap                55.465853
# theaters_viewers_per_1000_cap             55.465853
# load_of_teachers_preschool_per_teacher    55.465853
# hospital_beds_raion                       47.392603
# build_year                                44.649011
# state                                     44.498047
# cafe_sum_500_max_price_avg                43.585704
# cafe_sum_500_min_price_avg                43.585704
# cafe_avg_price_500                        43.585704
# material                                  31.413475
# kitch_sq                                  31.413475
# num_room                                  31.413475
# max_floor                                 31.413475
# preschool_quota                           21.948738
# school_quota                              21.938893
# ...
